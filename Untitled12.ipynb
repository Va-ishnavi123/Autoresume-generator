# %%
# !pip install fpdf PyPDF2 nltk
from fpdf import FPDF
from PyPDF2 import PdfReader
from google.colab import files
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# import nltk
nltk.download('punkt_tab')



nltk.download('stopwords')
nltk.download('punkt')

# Function to clean text of non-ASCII characters
def clean_text(text):
    return re.sub(r'[^\x00-\x7F]+', '', text)

# Function to extract sections from a PDF file
def extract_sections_from_pdf(file_path):
    reader = PdfReader(file_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text() or ""

    sections = {
        "Name": "",
        "Position": "",
        "Email": "",
        "Contact": "",
        "Education": "",
        "Skills": "",
        "Experience": "",
        "Projects": "",
        "Achievements": "",
        "Coding Profile": ""
    }

    current_section = None
    lines = text.splitlines()

    for line in lines:
        line = line.strip()
        for section in sections:
            if line.startswith(section):
                current_section = section
                break
        else:
            if current_section:
                sections[current_section] += line + "\n"

    return sections

# Function to extract keywords based on job description
def extract_keywords(job_description):
    stop_words = set(stopwords.words('english'))
    words = word_tokenize(job_description.lower())
    keywords = [word for word in words if word.isalpha() and word not in stop_words]
    # code = code.replace('\U+00A0', ' ')


#     # Customize the skills list here
#     relevant_skills = [
#     "html", "css", "javascript", "typescript", "react", "vue", "angular", "bootstrap", "jquery", "sass", "less",
#     "node.js", "express", "django", "flask", "php", "ruby", "wordpress", "mongodb", "mysql", "postgresql", "sql",
#     "graphql", "restful APIs", "json", "ajax", "web performance optimization", "cross-browser compatibility", "responsive design",
#     "seo", "git", "docker", "kubernetes", "cloud deployment", "serverless architecture", "CI/CD pipelines",

#     "java", "c++", "c#", "python", "go", "swift", "scala", "rust", "node.js", "java spring", "express", "redis", "rabbitmq",
#     "kafka", "mongodb", "postgresql", "mysql", "oracle", "noSQL", "firebase", "firebase functions", "webhooks", "api integration",

#     "aws", "azure", "gcp", "linux", "bash", "shell scripting", "terraform", "jenkins", "ansible", "chef", "puppet", "cloudformation",
#     "cloud storage", "cloud computing", "server management", "load balancing", "scaling", "networking", "virtualization", "docker compose",
#     "kubernetes", "continuous integration", "continuous delivery", "monitoring tools", "logging", "alerting",

#     "python", "r", "machine learning", "deep learning", "tensorflow", "pytorch", "scikit-learn", "pandas", "numpy", "matplotlib",
#     "data visualization", "model deployment", "data wrangling", "data cleaning", "nlp", "reinforcement learning", "anomaly detection",
#     "big data", "hadoop", "spark", "dask", "apache flink", "data pipelines", "bigquery", "tableau", "powerbi", "sql for data science",

#     "network security", "penetration testing", "firewalls", "malware analysis", "incident response", "ethical hacking", "encryption",
#     "ssl/tls", "vpn", "vulnerability assessment", "risk management", "security protocols", "siem", "iso 27001", "gdpr", "incident management",

#     "android", "ios", "flutter", "react native", "swift", "kotlin", "xcode", "android studio", "firebase", "app design", "mobile testing",

#     "adobe photoshop", "adobe illustrator", "figma", "sketch", "invision", "prototyping", "wireframing", "user research", "usability testing",
#     "interaction design", "user interface design", "user experience design", "UI patterns", "material design",

#     "agile", "scrum", "kanban", "lean", "jira", "trello", "confluence", "project management", "team collaboration", "budgeting", "stakeholder management",
#     "risk management", "communication", "documentation", "quality assurance", "resource planning", "milestone tracking",

#     "video editing", "adobe premiere pro", "final cut pro", "after effects", "motion graphics", "color grading", "audio editing", "3d modeling",
#     "animation", "film production", "photography", "photo editing", "content creation", "youtube content", "streaming",
#     "business analysis", "salesforce", "crm", "marketing automation", "market research", "data analysis", "product management",
#     "financial modeling", "investment banking", "business intelligence", "e-commerce", "legal research", "supply chain management", "logistics",
#     "human resources", "recruitment", "event planning", "content writing", "public speaking", "customer support", "public relations",
#     "negotiation", "product photography", "social media management", "brand development", "advertising", "digital marketing", "seo",
#     "data entry", "translation", "transcription"

#         "python", "java", "javascript", "data analysis", "react", "node.js",
#         "project management", "machine learning", "communication", "html", "css", "sql"
#     ]
#     relevant_skills = [
#     "html", "css", "javascript", "typescript", "react", "vue", "angular", "bootstrap",
#     "jquery", "sass", "less", "node.js", "express", "django", "flask", "php", "ruby",
#     "wordpress", "mongodb", "mysql", "postgresql", "sql", "graphql", "restful APIs",
#     "json", "ajax", "web performance optimization", "responsive design", "seo", "git"
# ]


    relevant_skills = ["html", "css", "javascript", "typescript", "react", "vue", "angular", "bootstrap", "jquery", "sass", "less",
    "node.js", "express", "django", "flask", "php", "ruby", "mongodb", "mysql", "postgresql", "sql", "graphql",
    "json", "ajax", "restful apis", "java", "c++", "python", "docker", "kubernetes", "git", "ci/cd", "cloud computing",
    "aws", "azure", "gcp", "tensorflow", "pytorch", "machine learning", "data analysis", "data visualization",
    "android", "ios", "flutter", "react native", "project management", "jira", "agile", "scrum", "web development",
    "software development", "testing", "quality assurance", "data engineering", "devops", "blockchain", "cybersecurity",
    "automation", "artificial intelligence", "nlp", "big data", "networking", "system administration", "frontend",
    "backend", "full stack development", "API integration", "UI/UX design", "wireframing", "prototyping",
    "performance optimization", "version control", "microservices", "shell scripting", "embedded systems",
    "ar/vr development", "data mining", "ETL", "business intelligence", "product management", "robotics",
    "e-commerce platforms", "game development", "3d modeling", "augmented reality", "virtual reality",
    "digital marketing", "seo", "sem", "crm tools", "erp systems", "salesforce", "shopify", "wordpress",
    "content management systems", "middleware technologies", "quantitative analysis", "biostatistics",
    "regression modeling", "geospatial analysis", "financial modeling", "nosql databases", "web scraping",
    "linux administration", "windows server management", "sap", "oracle", "hadoop", "spark", "elastic stack",
    "kafka", "iot development", "biometrics", "ethical hacking", "penetration testing", "forensics",

    # Expanded Non-Technical Skills
    "communication", "teamwork", "problem-solving", "critical thinking", "adaptability", "time management",
    "leadership", "creativity", "collaboration", "decision-making", "presentation skills", "interpersonal skills",
    "negotiation", "conflict resolution", "emotional intelligence", "customer service", "strategic planning",
    "organizational skills", "public speaking", "attention to detail", "multitasking", "initiative",
    "self-motivation", "work ethic", "cultural awareness", "research", "analytical skills", "coaching",
    "mentorship", "relationship building", "branding", "team building", "budgeting", "event planning",
    "stakeholder management", "employee engagement", "content writing", "storytelling", "persuasion skills",
    "user empathy", "influencing others", "vision setting", "crisis management", "policy development",
    "task prioritization", "process improvement"

    ]
#     relevant_skills = [
#     "html", "css", "javascript", "typescript", "react", "vue", "angular", "bootstrap",
#     "jquery", "sass", "less", "node.js", "express", "django", "flask", "php", "ruby",
#     "wordpress", "mongodb", "mysql", "postgresql", "sql", "graphql", "restful APIs",
#     "json", "ajax", "web performance optimization", "responsive design", "seo", "git"
# ]


    extracted_skills = [skill for skill in relevant_skills if skill in keywords]
    return extracted_skills

# Function to create the final resume
def create_resume(sections, name, position, contact, email, job_keywords=None):
    pdf = FPDF()
    pdf.add_page()
    pdf.set_auto_page_break(auto=True, margin=5)

    pdf.set_font("Arial", "B", 10)
    pdf.cell(200, 6, "Resume", ln=True, align="C")
    pdf.ln(3)

    pdf.set_font("Arial", "B", 8)
    pdf.cell(0, 5, f"Name: {clean_text(name)}", ln=True)
    pdf.cell(0, 5, f"Position Applied: {clean_text(position)}", ln=True)
    pdf.cell(0, 5, f"Contact: {clean_text(contact)}", ln=True)
    pdf.cell(0, 5, f"Email: {clean_text(email)}", ln=True)
    pdf.ln(3)

    for section in ["Education", "Skills", "Experience", "Projects", "Achievements", "Coding Profile"]:
        pdf.set_font("Arial", "B", 8)
        pdf.cell(0, 5, f"{section}:", ln=True)
        pdf.set_font("Arial", "", 7)

        # Set existing content and job keywords for Skills section
        existing_content = clean_text(sections[section])

        if section == "Skills":
            if job_keywords:
                skills_text = ", ".join(job_keywords)
                existing_content += f"\n {skills_text}"

        # Get user input for the section, append to existing content if provided
        user_input = input(f"Enter your {section.lower()} details (or press enter to keep existing): ")
        content = existing_content + "\n" + clean_text(user_input) if user_input else existing_content

        # Write the content to the PDF
        if content.strip():
            pdf.multi_cell(0, 4, content)
            pdf.ln(2)
        else:
            print(f"No details provided for {section}. Skipping.")

    pdf.output("generated_resume.pdf")
    print("Resume generated as 'generated_resume.pdf'")

# Step 1: Upload PDF file through the Files tab in Colab if upload widget doesn't work
print("If the upload widget does not work, upload the PDF manually through the Files tab on the left.")
uploaded = files.upload()
uploaded_resume_path = list(uploaded.keys())[0] if uploaded else "/content/uploaded_resume.pdf"

# Extract sections from uploaded resume
sections = extract_sections_from_pdf(uploaded_resume_path) if uploaded_resume_path else {}

# Basic info inputs if not present in uploaded resume
name = sections.get("Name") or input("Enter your name: ")
position = sections.get("Position") or input("Enter the position you are applying for: ")
contact = sections.get("Contact") or input("Enter your contact number: ")
email = sections.get("Email") or input("Enter your email: ")

# Get job description from user and extract keywords
job_description = input("Enter the job description to extract relevant skills: ")
job_keywords = extract_keywords(job_description)

# Generate resume with content from uploaded resume if available
create_resume(sections, name, position, contact, email, job_keywords=job_keywords)

# Download the PDF in Google Colab
files.download("generated_resume.pdf")
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.7 MB/s eta 0:00:00
# ...
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=2d8464d142ce406dfae09cd62901f9939c7a72ff342616fa6b182ffaa1edfabe
#   Stored in directory: /root/.cache/pip/wheels/f9/95/ba/f418094659025eb9611f17cbcaf2334236bf39a0c3453ea455
# Successfully built fpdf
# ...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# If the upload widget does not work, upload the PDF manually through the Files tab on the left.
#      <input type="file" id="files-170aa552-d143-4ce3-b298-690a2257d10c" name="files[]" multiple disabled
#         style="border:none" />
# ...
